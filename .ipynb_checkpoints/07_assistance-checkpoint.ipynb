# %%
'''different test to accelerate: store the classifier, see if several fit one same classifier doesn't change anything, control time of each process '''
# Out:
# 'lets try to store the classifiers intead of guessing right now'

# %%
import time
import pickle
from treatment import *
from sklearn.neighbors import KNeighborsClassifier

# %%
folder='D:/IA/Kaggle/Facebook/'
train='train.csv'
test='test.csv'

# %%
# Classifier choice

cut=20,20
cell_gen=cut_in(*cut)

dx,dy,dt=0.15,0.15,400

#[x,y,acc,minute(1day), day]
weights=[1,1.6,0,0.00012,0.0005]

# %%
#  Let's start

for cx in range(13,18):
    print('start of the '+str(cx)+' on x')
    for cy in range(20):
        t=time.time()
        with open(folder+'output'+str(cx)+'_'+str(cy)+'.csv', 'w',newline='') as file:
            writter = csv.writer(file)
            knn = KNeighborsClassifier(n_neighbors=40, 
                           algorithm='auto',
                           weights='distance',#'uniform' or 'distance'
                           metric='minkowski',
                           p=1,
                           metric_params=None, 
                           leaf_size=40, 
                           n_jobs=1)
            ###
            print('create init in ',str(t-time.time()))
            t=time.time()
            ##
            Xl,Yl=cell_gen(cx,cy)
            print('start the ',Xl,Yl)
            transform=lambda va,vb,vc,vd,ve,vf:(float(vb),float(vc),int(vd),int(ve)%1440,int(ve)//1440,int(vf))
            h,s,b=extract_from(folder+train,Xl,Yl,dx,dy,transform)
            ###
            print('read train in ',str(t-time.time()))
            t=time.time()
            ##
            transform=lambda va,vb,vc,vd,ve:(float(vb),float(vc),int(vd),int(ve)%1440,int(ve)//1440,int(va))
            h,u,_=extract_from(folder+test,Xl,Yl,0,0,transform)
            ###
            print('read output in ',str(t-time.time()))
            t=time.time()
            ##
            s+=extend_from(s,dt=dt)[0]
            b+=extend_from(b,dt=dt)[0]
            tot=s+b
            X,y=separate_column(tot,col=5)
            Xt,idt=separate_column(u,col=5)
            ###
            print('prepare sets in ',str(t-time.time()))
            t=time.time()
            ##
            knn.fit(X*weights, y)
            ###
            print('fit in ',str(t-time.time()))
            t=time.time()
            ##
            result=n_best(knn,Xt,n=3)
            ###
            print('guess in ',str(t-time.time()))
            t=time.time()
            ##
            for i,r in zip(idt,result):
                line=[i," ".join([str(i) for i in r])]
                writter.writerow(line)
            print('finished the ',Xl,Yl,'!')
            ###
            print('write output in ',str(t-time.time()))
            t=time.time()
            ##
    print('finished the ',cx,' file !!!')
# Out:
# start of the 18 on x
# create init in  -1.49202561378479
# start the  (9.0, 9.5) (0.0, 0.5)
# read train in  -320.5196352005005
# read output in  -86.78896403312683
# prepare sets in  -0.8190469741821289
# fit in  -0.6830391883850098
# guess in  -105.58503913879395
# finished the  (9.0, 9.5) (0.0, 0.5) !
# write output in  -7.229172945022583
# create init in  -3.0330142974853516
# start the  (9.0, 9.5) (0.5, 1.0)
# read train in  -330.96366143226624
# read output in  -120.77878832817078
# prepare sets in  -21.132208824157715
# fit in  -5.870335817337036
# guess in  -24.956427335739136
# finished the  (9.0, 9.5) (0.5, 1.0) !
# write output in  -0.5440309047698975
# create init in  -0.0030002593994140625
# start the  (9.0, 9.5) (1.0, 1.5)
# read train in  -377.09312891960144
# read output in  -86.1511013507843
# prepare sets in  -1.124056339263916
# fit in  -0.7950453758239746
# guess in  -22.060261726379395
# finished the  (9.0, 9.5) (1.0, 1.5) !
# write output in  -0.49402832984924316
# create init in  -0.0030002593994140625
# start the  (9.0, 9.5) (1.5, 2.0)
# read train in  -401.2017216682434
# read output in  -87.28198313713074
# prepare sets in  -3.7772104740142822
# fit in  -0.9080519676208496
# guess in  -206.87912368774414
# finished the  (9.0, 9.5) (1.5, 2.0) !
# write output in  -3.6093225479125977
# create init in  -3.544008255004883
# start the  (9.0, 9.5) (2.0, 2.5)
# read train in  -442.31360721588135
# read output in  -108.81622409820557
# prepare sets in  -8.329417943954468
# fit in  -2.8161611557006836
# guess in  -22.847306728363037
# finished the  (9.0, 9.5) (2.0, 2.5) !
# write output in  -0.8550488948822021
# create init in  -0.03800225257873535
# start the  (9.0, 9.5) (2.5, 3.0)
# read train in  -369.76647186279297
# read output in  -64.09046936035156
# prepare sets in  -0.810011625289917
# fit in  -0.5866024494171143
# guess in  -15.78086543083191
# finished the  (9.0, 9.5) (2.5, 3.0) !
# write output in  -0.42580461502075195
# create init in  0.0
# start the  (9.0, 9.5) (3.0, 3.5)
# read train in  -235.1595435142517
# read output in  -64.62212133407593
# prepare sets in  -0.7704017162322998
# fit in  -0.565601110458374
# guess in  -16.67486023902893
# finished the  (9.0, 9.5) (3.0, 3.5) !
# write output in  -0.4086008071899414
# create init in  0.0
# start the  (9.0, 9.5) (3.5, 4.0)
# read train in  -233.0122091770172
# read output in  -63.684569120407104
# prepare sets in  -0.7206013202667236
# fit in  -0.5624027252197266
# guess in  -16.28547191619873
# finished the  (9.0, 9.5) (3.5, 4.0) !
# write output in  -0.40580320358276367
# create init in  0.0
# start the  (9.0, 9.5) (4.0, 4.5)
# read train in  -231.60165286064148
# read output in  -63.28661298751831
# prepare sets in  -0.7874026298522949
# fit in  -0.6114013195037842
# guess in  -16.828054428100586
# finished the  (9.0, 9.5) (4.0, 4.5) !
# write output in  -0.45980191230773926
# create init in  0.0
# start the  (9.0, 9.5) (4.5, 5.0)
# read train in  -236.68533778190613
# read output in  -63.356401681900024
# prepare sets in  -0.7190065383911133
# fit in  -0.518801212310791
# guess in  -19.277655124664307
# finished the  (9.0, 9.5) (4.5, 5.0) !
# write output in  -0.4720008373260498
# create init in  0.0
# start the  (9.0, 9.5) (5.0, 5.5)
# read train in  -243.52644443511963
# read output in  -63.45598483085632
# prepare sets in  -0.7520041465759277
# fit in  -0.5050029754638672
# guess in  -16.226653814315796
# finished the  (9.0, 9.5) (5.0, 5.5) !
# write output in  -0.39440178871154785
# create init in  0.0
# start the  (9.0, 9.5) (5.5, 6.0)
# read train in  -236.22112035751343
# read output in  -63.45126128196716
# prepare sets in  -0.7592027187347412
# fit in  -0.5380048751831055
# guess in  -16.219640493392944
# finished the  (9.0, 9.5) (5.5, 6.0) !
# write output in  -0.42440342903137207
# create init in  0.0
# start the  (9.0, 9.5) (6.0, 6.5)
# read train in  -237.33379530906677
# read output in  -64.58723759651184
# prepare sets in  -0.7822039127349854
# fit in  -0.584003210067749
# guess in  -19.697041273117065
# finished the  (9.0, 9.5) (6.0, 6.5) !
# write output in  -0.514801025390625
# create init in  0.0
# start the  (9.0, 9.5) (6.5, 7.0)
# read train in  -237.26553058624268
# read output in  -64.30769300460815
# prepare sets in  -0.7680048942565918
# fit in  -0.6084012985229492
# guess in  -17.304831504821777
# finished the  (9.0, 9.5) (6.5, 7.0) !
# write output in  -0.4156012535095215
# create init in  0.0
# start the  (9.0, 9.5) (7.0, 7.5)
# read train in  -238.08142566680908
# read output in  -63.360116958618164
# prepare sets in  -0.8142015933990479
# fit in  -0.6162033081054688
# guess in  -17.33657217025757
# finished the  (9.0, 9.5) (7.0, 7.5) !
# write output in  -0.48602771759033203
# create init in  -0.03800225257873535
# start the  (9.0, 9.5) (7.5, 8.0)
# read train in  -236.5121030807495
# read output in  -63.93498873710632
# prepare sets in  -0.7204031944274902
# fit in  -0.5508029460906982
# guess in  -16.274828672409058
# finished the  (9.0, 9.5) (7.5, 8.0) !
# write output in  -0.4228043556213379
# create init in  -0.015599966049194336
# start the  (9.0, 9.5) (8.0, 8.5)
# read train in  -234.6407985687256
# read output in  -67.63193607330322
# prepare sets in  -0.8078305721282959
# fit in  -0.6608266830444336
# guess in  -18.174463510513306
# finished the  (9.0, 9.5) (8.0, 8.5) !
# write output in  -0.4554011821746826
# create init in  0.0
# start the  (9.0, 9.5) (8.5, 9.0)
# read train in  -257.9130713939667
# read output in  -63.79373645782471
# prepare sets in  -0.8202064037322998
# fit in  -0.6370363235473633
# guess in  -19.13034224510193
# finished the  (9.0, 9.5) (8.5, 9.0) !
# write output in  -0.4836008548736572
# create init in  0.0
# start the  (9.0, 9.5) (9.0, 9.5)
# read train in  -314.4954135417938
# read output in  -80.62361145019531
# prepare sets in  -1.0450596809387207
# fit in  -0.7720441818237305
# guess in  -27.71758532524109
# finished the  (9.0, 9.5) (9.0, 9.5) !
# write output in  -0.596034049987793
# create init in  -0.003000020980834961
# start the  (9.0, 9.5) (9.5, 10.0)
# read train in  -324.14950132369995
# read output in  -97.27156376838684
# prepare sets in  -0.8730499744415283
# fit in  -0.47902750968933105
# guess in  -14.818847417831421
# finished the  (9.0, 9.5) (9.5, 10.0) !
# write output in  -0.49202799797058105
# finished the  18  file !!!

# %%
t=time.time()

# %%
print(time.time()-t)

# %%
#  -> check if don't need to load the data to use the picked classifier
#  -> see if train on former is not a big deal
